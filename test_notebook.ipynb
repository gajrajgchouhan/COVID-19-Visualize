# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from COUNTRY import STATES

with open("states_daily.json", "r") as read_file:
    data = json.load(read_file)["states_daily"]

data = pd.DataFrame(data)
data = data.apply(pd.to_numeric, errors='ignore')
dates = list(data["date"].drop_duplicates())
data["date"] = pd.to_datetime(data['date'])

state = "rj"
data = data.loc[:, [state, "status", "date"]]
color = ["Blue", "Green", "Red"]

i = 0

fig, ax = plt.subplots()
for status, st_data in data.groupby("status"):
    X = range(len(dates))
    Y = st_data[state]
    ax.plot(X, Y, "-k", Color=color[i], label=status, markersize=5)
    i += 1
plt.legend()
annot = ax.annotate(
    "",
    xy=(0, 0),
    xytext=(20, 20),
    textcoords="offset points",
    bbox=dict(boxstyle="round", fc="w"),
    arrowprops=dict(arrowstyle="->"),
)
annot.set_visible(False)
plt.legend(loc="upper left")
plt.show()
# Out:
# <ipython-input-90-9ec6d9eda5de>:25: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.plot(X, Y, "-k", Color=color[i], label=status, markersize=5)
# <ipython-input-90-9ec6d9eda5de>:25: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.plot(X, Y, "-k", Color=color[i], label=status, markersize=5)
# <ipython-input-90-9ec6d9eda5de>:25: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.plot(X, Y, "-k", Color=color[i], label=status, markersize=5)
